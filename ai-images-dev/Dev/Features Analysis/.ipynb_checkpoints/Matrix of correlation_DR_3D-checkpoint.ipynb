# %% [markdown]
# ### Necessary libraries

# %%
import os
import sys
import time
import numpy
import warnings
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import KFold, cross_val_score, RandomizedSearchCV, train_test_split

# %% [markdown]
# ### REPOSITORY PATH OF PROJECT

# %%
#REPOSITORY PATH OF PROJECT
(Tempo,_) = os.path.split(os.getcwd())
Tempo,_ = os.path.split(Tempo)
PATH_PROJECT,DEV = os.path.split(Tempo)
PATH_DEV = os.path.join(PATH_PROJECT,'Dev')
PATH_DATA = os.path.join(PATH_PROJECT,'Data')
PATH_DATA_IMAGES = os.path.join(PATH_DATA,'Data Images')
DATA_CBIRH_5_500 = os.path.join(PATH_DATA_IMAGES,'DATA_CBIRH_5_500')
#path of 3 descriptors
PATH_DATA_CSV_3 = os.path.join(os.path.join(os.path.join(PATH_DATA,'Data Descriptors'),'Data Feautures_5_500'),'Three descriptors')
LIST_CLASS_3 =os.listdir(PATH_DATA_CSV_3)

print(LIST_CLASS_3)
len(LIST_CLASS_3)
# Out:
# ['DF_CH_FG_HM.csv', 'DF_CH_FG_SIFT.csv', 'DF_CH_GCM_HM.csv', 'DF_CH_GCM_SIFT.csv', 'DF_CH_TH_HM.csv', 'DF_CH_TH_SIFT.csv', 'DF_DCD_FG_HM.csv', 'DF_DCD_FG_SIFT.csv', 'DF_DCD_GCM_HM.csv', 'DF_DCD_GCM_SIFT.csv', 'DF_DCD_TH_HM.csv', 'DF_DCD_TH_SIFT.csv']
# 12

# %%
score_rf = []
score_ml = []

# %% [markdown]
# ### Methods

# %%
# build path
def path_build(PATH_DATA_CSV):
    List_DF = []
    List_DF_without_header = []
    for i in os.listdir(PATH_DATA_CSV):
        if i.find('SIFT') !=-1 or i.find('FG') !=-1:
            List_DF_without_header.append((i,PATH_DATA_CSV+"/"+i))
        else:
            List_DF.append((i,PATH_DATA_CSV+"/"+i))
    return List_DF,List_DF_without_header
#split data to X,y
def split_data(path):
    DF = pd.read_csv(path)
    DF = DF.iloc[:,1::] 
    y =  DF.label 
    del DF['label']
    X = DF
    return X,y

#split data to X,y
def split_data_without_head(path):
    DF = pd.read_csv(path)
    DF = DF.iloc[:,1::] 
    y =  y=DF[DF.columns[-1]] 
    del DF[DF.columns[-1]]
    X = DF
    return X,y

#plot confusion matrix
def plot_confusion_catrix(cm):
    
    sb.set(rc={'figure.figsize':(8,8)})
    sb.set(font_scale=1.4)#for label size
    ax = sb.heatmap(cm, annot=True, cmap ='Oranges', cbar=False)
    ax.set_title('Confusion Matrix with labels\n')
    ax.set_xlabel('\nPredicted Label')
    ax.set_ylabel('\nTrue Label ')
    _= ax.xaxis.set_ticklabels(['CAR','DOG','FRUIT','PERSON','CAT'])
    _= ax.yaxis.set_ticklabels(['CAR','DOG','FRUIT','PERSON','CAT'])
    
#tuning hyperparameter of model   
def hyperparameter_tuning_randomrorestClassifier(xtrain,ytrain,xtest,ytest):
    start = time.time()
    rfc=RandomForestClassifier(bootstrap = False)   
    param_grid = {  'n_estimators': list(np.arange(100, 1000, 100)),
                'criterion' :['gini', 'entropy'],
                'max_depth' : np.arange(3, 10, 2),
                'min_samples_split' : np.arange(2, 10, 2),
                'max_features': ['auto', 'sqrt', 'log2', None],
                'bootstrap': [True, False]
             }
    kf = KFold(n_splits=5, random_state = 0, shuffle = True)
    randomizedsearch = RandomizedSearchCV(estimator=rfc, param_distributions=param_grid,scoring='accuracy', cv= kf)
    randomizedsearch.fit(xtrain, ytrain)
    end = time.time()
    run_time = end - start
    print("[INFO] Applying took {:.2f} seconds".format(run_time))
    return randomizedsearch

#tuning hyperparameter of model   
def hyperparameter_tuning_MultiLayerPerceptron(xtrain,ytrain,xtest,ytest):
    start = time.time()
    MLP=MLPClassifier(max_iter=250)   
    parameter_space = {
        'hidden_layer_sizes': [(150,100,50), (120,80,40), (100,50,30)],
        'max_iter': [50, 100, 150],
        'activation': ['tanh', 'relu','logistic'],
        'solver': ['sgd', 'adam','lbfgs'],
        'alpha': [0.0001, 0.09],
        'learning_rate': ['constant','adaptive'],
    }
    kf = KFold(n_splits=5, random_state = 0, shuffle = True)
    randomizedsearch = RandomizedSearchCV(estimator=MLP, param_distributions=parameter_space,n_iter = 100,
                                          scoring='accuracy', cv= kf)
    randomizedsearch.fit(xtrain, ytrain)
    end = time.time()
    run_time = end - start
    print("[INFO] Applying took {:.2f} seconds".format(run_time))
    return randomizedsearch

#evaluate of result
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    accuracy = accuracy_score(test_labels, predictions)
    errors = 1-accuracy
    Confusion_Matrix = confusion_matrix(test_labels, predictions)
    print('[INFO] Model Performance')
    print('[INFO] Average Error: {:0.2f} %.'.format(np.mean(errors)))
    print('[INFO] Accuracy = {:0.2f}%.'.format(accuracy))
    print('[INFO] Classification_report :\n',classification_report(test_labels,predictions))
    print('[INFO] Confusion_Matrix : \n')
    plot_confusion_catrix(Confusion_Matrix)

# %%
List_DF,List_DF_without_header = path_build(PATH_DATA_CSV_3)
print(len(List_DF))
print(len(List_DF_without_header))
# Out:
# 4
# 8

# %%
LIST_CLASS = []
for i in range(len(List_DF)) :
    LIST_CLASS.append(List_DF[i][0])
for i in range(len(List_DF_without_header)) :
    LIST_CLASS.append(List_DF_without_header[i][0])    

print(LIST_CLASS)
# Out:
# ['DF_CH_GCM_HM.csv', 'DF_CH_TH_HM.csv', 'DF_DCD_GCM_HM.csv', 'DF_DCD_TH_HM.csv', 'DF_CH_FG_HM.csv', 'DF_CH_FG_SIFT.csv', 'DF_CH_GCM_SIFT.csv', 'DF_CH_TH_SIFT.csv', 'DF_DCD_FG_HM.csv', 'DF_DCD_FG_SIFT.csv', 'DF_DCD_GCM_SIFT.csv', 'DF_DCD_TH_SIFT.csv']

# %% [markdown]
# ### DF_CH_GCM_HM

# %%
num_df = 0
print("Data Features Study : ",List_DF[num_df][0])
X,y = split_data(List_DF[num_df][1])
print(X.shape, len(y))
# Out:
# Data Features Study :  DF_CH_GCM_HM.csv
# (500, 24) 500

# %%
correlation_matrix  = X.corr(method='pearson')#
"""plt.figure(figsize=(30, 30))
sb.heatmap(correlation_matrix , annot=True)
plt.show()"""
# Out:
# 'plt.figure(figsize=(30, 30))\nsb.heatmap(correlation_matrix , annot=True)\nplt.show()'

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 13

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 56.19 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.15 %.
# [INFO] Accuracy = 0.85%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       0.68      0.68      0.68        25
#            2       0.64      0.62      0.63        26
#            3       1.00      1.00      1.00        28
#            4       0.96      0.96      0.96        24
#
#     accuracy                           0.85       125
#    macro avg       0.85      0.85      0.85       125
# weighted avg       0.85      0.85      0.85       125
#
# [INFO] Confusion_Matrix :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 331.17 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.30 %.
# [INFO] Accuracy = 0.70%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80        22
#            1       0.50      0.48      0.49        25
#            2       0.52      0.46      0.49        26
#            3       0.96      0.96      0.96        28
#            4       0.70      0.79      0.75        24
#
#     accuracy                           0.70       125
#    macro avg       0.69      0.70      0.70       125
# weighted avg       0.70      0.70      0.70       125
#
# [INFO] Confusion_Matrix :

# %% [markdown]
# ## DF_CH_TH_HM

# %%
num_df = 1
print("Data Features Study : ",List_DF[num_df][0])
X,y = split_data(List_DF[num_df][1])
print(X.shape, len(y))
# Out:
# Data Features Study :  DF_CH_TH_HM.csv
# (500, 23) 500

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 14

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 84.06 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.18 %.
# [INFO] Accuracy = 0.82%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       0.62      0.40      0.49        25
#            2       0.55      0.69      0.61        26
#            3       1.00      1.00      1.00        28
#            4       0.96      1.00      0.98        24
#
#     accuracy                           0.82       125
#    macro avg       0.82      0.82      0.81       125
# weighted avg       0.82      0.82      0.81       125
#
# [INFO] Confusion_Matrix :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 346.75 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.43 %.
# [INFO] Accuracy = 0.57%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.72      0.82      0.77        22
#            1       0.29      0.24      0.26        25
#            2       0.35      0.23      0.28        26
#            3       0.93      1.00      0.97        28
#            4       0.41      0.54      0.46        24
#
#     accuracy                           0.57       125
#    macro avg       0.54      0.57      0.55       125
# weighted avg       0.54      0.57      0.55       125
#
# [INFO] Confusion_Matrix :

# %% [markdown]
# ## DF_DCD_GCM_HM

# %%
num_df = 2
print("Data Features Study : ",List_DF[num_df][0])
X,y = split_data(List_DF[num_df][1])
print(X.shape, len(y))
# Out:
# Data Features Study :  DF_DCD_GCM_HM.csv
# (500, 24) 500

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 3

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 99.51 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.25 %.
# [INFO] Accuracy = 0.75%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85        22
#            1       0.55      0.44      0.49        25
#            2       0.54      0.54      0.54        26
#            3       1.00      1.00      1.00        28
#            4       0.81      0.88      0.84        24
#
#     accuracy                           0.75       125
#    macro avg       0.74      0.75      0.74       125
# weighted avg       0.74      0.75      0.74       125
#
# [INFO] Confusion_Matrix :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 344.81 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.37 %.
# [INFO] Accuracy = 0.63%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78        22
#            1       0.39      0.44      0.42        25
#            2       0.52      0.50      0.51        26
#            3       0.92      0.82      0.87        28
#            4       0.61      0.58      0.60        24
#
#     accuracy                           0.63       125
#    macro avg       0.64      0.63      0.63       125
# weighted avg       0.64      0.63      0.64       125
#
# [INFO] Confusion_Matrix :

# %% [markdown]
# ## DF_DCD_TH_HM

# %%
num_df = 3
print("Data Features Study : ",List_DF[num_df][0])
X,y = split_data(List_DF[num_df][1])
print(X.shape, len(y))
# Out:
# Data Features Study :  DF_DCD_TH_HM.csv
# (500, 23) 500

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 2

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 129.01 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.19 %.
# [INFO] Accuracy = 0.81%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        22
#            1       0.74      0.56      0.64        25
#            2       0.61      0.54      0.57        26
#            3       1.00      1.00      1.00        28
#            4       0.79      0.96      0.87        24
#
#     accuracy                           0.81       125
#    macro avg       0.80      0.81      0.80       125
# weighted avg       0.80      0.81      0.80       125
#
# [INFO] Confusion_Matrix :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 358.31 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.37 %.
# [INFO] Accuracy = 0.63%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81        22
#            1       0.33      0.28      0.30        25
#            2       0.50      0.35      0.41        26
#            3       0.93      0.96      0.95        28
#            4       0.53      0.71      0.61        24
#
#     accuracy                           0.63       125
#    macro avg       0.61      0.63      0.62       125
# weighted avg       0.61      0.63      0.62       125
#
# [INFO] Confusion_Matrix :

# %% [markdown]
# ## DF_CH_GCM_HM

# %%
num_df = 0
print("Data Features Study : ",List_DF[num_df][0])
X,y = split_data_without_head(List_DF[num_df][1])
print(X.shape, len(y))
# Out:
# Data Features Study :  DF_CH_GCM_HM.csv
# (500, 24) 500

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 13

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 89.82 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.17 %.
# [INFO] Accuracy = 0.83%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       0.63      0.48      0.55        25
#            2       0.58      0.69      0.63        26
#            3       1.00      1.00      1.00        28
#            4       1.00      1.00      1.00        24
#
#     accuracy                           0.83       125
#    macro avg       0.83      0.83      0.83       125
# weighted avg       0.83      0.83      0.83       125
#
# [INFO] Confusion_Matrix :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 371.94 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.31 %.
# [INFO] Accuracy = 0.69%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78        22
#            1       0.50      0.48      0.49        25
#            2       0.43      0.35      0.38        26
#            3       0.96      0.96      0.96        28
#            4       0.71      0.83      0.77        24
#
#     accuracy                           0.69       125
#    macro avg       0.67      0.69      0.68       125
# weighted avg       0.67      0.69      0.68       125
#
# [INFO] Confusion_Matrix :

# %% [markdown]
# ## DF_CH_FG_SIFT

# %%
num_df = 1
print("Data Features Study : ",List_DF_without_header[num_df][0])
X,y = split_data_without_head(List_DF_without_header[num_df][1])
print(X.shape, len(y))
# Out:
# Data Features Study :  DF_CH_FG_SIFT.csv
# (500, 483) 500

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 150

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 528.18 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.21 %.
# [INFO] Accuracy = 0.79%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        22
#            1       0.56      0.36      0.44        25
#            2       0.52      0.65      0.58        26
#            3       1.00      0.96      0.98        28
#            4       0.96      1.00      0.98        24
#
#     accuracy                           0.79       125
#    macro avg       0.79      0.80      0.79       125
# weighted avg       0.79      0.79      0.78       125
#
# [INFO] Confusion_Matrix :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 499.82 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.75 %.
# [INFO] Accuracy = 0.25%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.17      0.18      0.18        22
#            1       0.47      0.28      0.35        25
#            2       0.67      0.08      0.14        26
#            3       0.25      0.57      0.35        28
#            4       0.10      0.08      0.09        24
#
#     accuracy                           0.25       125
#    macro avg       0.33      0.24      0.22       125
# weighted avg       0.34      0.25      0.23       125
#
# [INFO] Confusion_Matrix :

# %% [markdown]
# ## DF_CH_GCM_SIFT

# %%
num_df = 2
print("Data Features Study : ",List_DF_without_header[num_df][0])
X,y = split_data_without_head(List_DF_without_header[num_df][1])
print(X.shape, len(y))
# Out:
# Data Features Study :  DF_CH_GCM_SIFT.csv
# (500, 413) 500

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 86

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 733.24 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.21 %.
# [INFO] Accuracy = 0.79%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        22
#            1       0.56      0.36      0.44        25
#            2       0.52      0.65      0.58        26
#            3       1.00      0.96      0.98        28
#            4       0.96      1.00      0.98        24
#
#     accuracy                           0.79       125
#    macro avg       0.79      0.80      0.79       125
# weighted avg       0.79      0.79      0.78       125
#
# [INFO] Confusion_Matrix :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 761.47 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.89 %.
# [INFO] Accuracy = 0.11%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.11      0.36      0.17        22
#            1       0.08      0.04      0.05        25
#            2       0.50      0.04      0.07        26
#            3       0.00      0.00      0.00        28
#            4       0.10      0.17      0.13        24
#
#     accuracy                           0.11       125
#    macro avg       0.16      0.12      0.08       125
# weighted avg       0.16      0.11      0.08       125
#
# [INFO] Confusion_Matrix :
# C:\Users\yousra.amrani_adm\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\yousra.amrani_adm\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\yousra.amrani_adm\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### DF_CH_TH_SIFT

# %%
num_df = 3
print("Data Features Study : ",List_DF_without_header[num_df][0])
X,y = split_data_without_head(List_DF_without_header[num_df][1])
print(X.shape, len(y))
# Out:
# Data Features Study :  DF_CH_TH_SIFT.csv
# (500, 412) 500

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)
# Out:
# 87

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))
# Out:
# [INFO] Applying took 1250.92 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.20 %.
# [INFO] Accuracy = 0.80%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        22
#            1       0.57      0.48      0.52        25
#            2       0.54      0.58      0.56        26
#            3       1.00      0.96      0.98        28
#            4       0.96      1.00      0.98        24
#
#     accuracy                           0.80       125
#    macro avg       0.80      0.80      0.80       125
# weighted avg       0.80      0.80      0.80       125
#
# [INFO] Confusion_Matrix :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))

# %% [markdown]
# ## DF_DCD_FG_HM

# %%
num_df = 4
print("Data Features Study : ",List_DF_without_header[num_df][0])
X,y = split_data_without_head(List_DF_without_header[num_df][1])
print(X.shape, len(y))

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))

# %% [markdown]
# ## DF_DCD_FG_SIFT

# %%
num_df = 5
print("Data Features Study : ",List_DF_without_header[num_df][0])
X,y = split_data_without_head(List_DF_without_header[num_df][1])
print(X.shape, len(y))

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))

# %% [markdown]
# ## DF_DCD_GCM_SIFT

# %%
num_df = 6
print("Data Features Study : ",List_DF_without_header[num_df][0])
X,y = split_data_without_head(List_DF_without_header[num_df][1])
print(X.shape, len(y))

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))

# %% [markdown]
# ## DF_DCD_TH_SIFT

# %%
num_df = 7
print("Data Features Study : ",List_DF_without_header[num_df][0])
X,y = split_data_without_head(List_DF_without_header[num_df][1])
print(X.shape, len(y))

# %%
correlation_matrix  = X.corr(method='pearson')#

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_rf.append(evaluate(clf,X_test,y_test))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
score_ml.append(evaluate(clf,X_test,y_test))

# %%
print(score_rf)
plt.figure(figsize=(20,5))
plt.bar(LIST_CLASS,score_rf,color=['orange', 'yellow', 'red','blue', 'green', 'pink','gray', 'black'])
for i,j in enumerate(score_rf) :
    plt.text(i,90,str(int(j))+'%', va = 'center', ha = 'center')
plt.xticks(LIST_CLASS,rotation=90)
plt.ylabel("Accuracy\n")
plt.title("   Graph Showing the accuracy of each data feautures descriptors\n")

# %%
print(score_ml)
plt.figure(figsize=(20,5))
plt.bar(LIST_CLASS,score_ml,color=['orange', 'yellow', 'red','blue', 'green', 'pink','gray', 'black'])
for i,j in enumerate(score_ml) :
    plt.text(i,90,str(int(j))+'%', va = 'center', ha = 'center')
plt.xticks(LIST_CLASS,rotation=90)
plt.ylabel("Accuracy\n")
plt.title("   Graph Showing the accuracy of each data feautures descriptors\n")
