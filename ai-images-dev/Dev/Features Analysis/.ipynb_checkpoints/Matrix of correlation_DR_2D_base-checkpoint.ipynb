# %%
import os
import sys
import time
import numpy
import warnings
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import KFold, cross_val_score, RandomizedSearchCV, train_test_split

# %%
"""#REPOSITORY PATH OF PROJECT
PATH_DEV_CLEAN = os.getcwd()
(PATH_DEV,_) = os.path.split(os.getcwd())
PATH_PROJECT,y = os.path.split(PATH_DEV)
#PATH_PHASE_TWO = os.path.join(PATH_PROJECT,'Phase_2')
PATH_DATA = os.path.join(PATH_PROJECT,'Data')
PATH_DATA_CBIRH = os.path.join(PATH_DATA,'DATA_CBIRH_1')
PATH_DATA_CSV = os.path.join(PATH_DATA,'Data_csv/Two descriptors')
LIST_CLASS = os.listdir(PATH_DATA_CBIRH)
print(os.listdir(PATH_DATA_CSV))"""
# Out:
# ['DF_CH_FG.csv', 'DF_CH_GCM.csv', 'DF_CH_TH.csv', 'DF_DCD_FG.csv', 'DF_DCD_GCM.csv', 'DF_DCD_TH.csv', 'DF_HM_CH.csv', 'DF_HM_DCD.csv', 'DF_HM_FG.csv', 'DF_HM_GCM.csv', 'DF_HM_TH.csv', 'DF_SIFT_CH.csv', 'DF_SIFT_DCD.csv', 'DF_SIFT_FG.csv', 'DF_SIFT_GCM.csv', 'DF_SIFT_TH.csv']

# %%
#REPOSITORY PATH OF PROJECT
(Tempo,_) = os.path.split(os.getcwd())
Tempo,_ = os.path.split(Tempo)
PATH_PROJECT,DEV = os.path.split(Tempo)
PATH_DEV = os.path.join(PATH_PROJECT,'Dev')
PATH_DATA = os.path.join(PATH_PROJECT,'Data')
PATH_DATA_IMAGES = os.path.join(PATH_DATA,'Data Images')
DATA_CBIRH_5_500 = os.path.join(PATH_DATA_IMAGES,'DATA_CBIRH_5_500')
PATH_DATA_CSV_2 = os.path.join(os.path.join(os.path.join(PATH_DATA,'Data Descriptors'),'Data Feautures_5_500'),'Two descriptors')
LIST_CLASS_2 =os.listdir(PATH_DATA_CSV_2)

print(LIST_CLASS_2)
# Out:
# ['DF_CH_FG.csv', 'DF_CH_GCM.csv', 'DF_CH_TH.csv', 'DF_DCD_FG.csv', 'DF_DCD_GCM.csv', 'DF_DCD_TH.csv', 'DF_HM_CH.csv', 'DF_HM_DCD.csv', 'DF_HM_FG.csv', 'DF_HM_GCM.csv', 'DF_HM_TH.csv', 'DF_SIFT_CH.csv', 'DF_SIFT_DCD.csv', 'DF_SIFT_FG.csv', 'DF_SIFT_GCM.csv', 'DF_SIFT_TH.csv']

# %%
# build path
def path_build(PATH_DATA_CSV):
    List_DF = []
    List_DF_without_header = []
    for i in os.listdir(PATH_DATA_CSV):
        if i.find('SIFT') !=-1 or i.find('FG') !=-1:
            List_DF_without_header.append((i,PATH_DATA_CSV+"/"+i))
        else:
            List_DF.append((i,PATH_DATA_CSV+"/"+i))
    return List_DF,List_DF_without_header

#split data to X,y
def split_data_without_head(path):
    DF = pd.read_csv(path)
    DF = DF.iloc[:,1::] 
    y =  y=DF[DF.columns[-1]] 
    del DF[DF.columns[-1]]
    X = DF
    return X,y

#plot confusion matrix
def plot_confusion_catrix(cm):
    
    sb.set(rc={'figure.figsize':(8,8)})
    sb.set(font_scale=1.4)#for label size
    ax = sb.heatmap(cm, annot=True, cmap ='Oranges', cbar=False)
    ax.set_title('Confusion Matrix with labels\n')
    ax.set_xlabel('\nPredicted Label')
    ax.set_ylabel('\nTrue Label ')
    _= ax.xaxis.set_ticklabels(['CAR','DOG','FRUIT','PERSON','CAT'])
    _= ax.yaxis.set_ticklabels(['CAR','DOG','FRUIT','PERSON','CAT'])
    
#tuning hyperparameter of model   
def hyperparameter_tuning_randomrorestClassifier(xtrain,ytrain,xtest,ytest):
    start = time.time()
    rfc=RandomForestClassifier(bootstrap = False)   
    param_grid = {  'n_estimators': list(np.arange(100, 1000, 100)),
                'criterion' :['gini', 'entropy'],
                'max_depth' : np.arange(3, 10, 2),
                'min_samples_split' : np.arange(2, 10, 2),
                'max_features': ['auto', 'sqrt', 'log2', None],
                'bootstrap': [True, False]
             }
    kf = KFold(n_splits=5, random_state = 0, shuffle = True)
    randomizedsearch = RandomizedSearchCV(estimator=rfc, param_distributions=param_grid,scoring='accuracy', cv= kf)
    randomizedsearch.fit(xtrain, ytrain)
    end = time.time()
    run_time = end - start
    print("[INFO] Applying took {:.2f} seconds".format(run_time))
    return randomizedsearch

#tuning hyperparameter of model   
def hyperparameter_tuning_MultiLayerPerceptron(xtrain,ytrain,xtest,ytest):
    start = time.time()
    MLP=MLPClassifier(max_iter=250)   
    parameter_space = {
        'hidden_layer_sizes': [(150,100,50), (120,80,40), (100,50,30)],
        'max_iter': [50, 100, 150],
        'activation': ['tanh', 'relu','logistic'],
        'solver': ['sgd', 'adam','lbfgs'],
        'alpha': [0.0001, 0.09],
        'learning_rate': ['constant','adaptive'],
    }
    kf = KFold(n_splits=5, random_state = 0, shuffle = True)
    randomizedsearch = RandomizedSearchCV(estimator=MLP, param_distributions=parameter_space,n_iter = 100,
                                          scoring='accuracy', cv= kf)
    randomizedsearch.fit(xtrain, ytrain)
    end = time.time()
    run_time = end - start
    print("[INFO] Applying took {:.2f} seconds".format(run_time))
    return randomizedsearch

#evaluate of result
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    accuracy = accuracy_score(test_labels, predictions)
    errors = 1-accuracy
    Confusion_Matrix = confusion_matrix(test_labels, predictions)
    print('[INFO] Model Performance')
    print('[INFO] Average Error: {:0.2f} %.'.format(np.mean(errors)))
    print('[INFO] Accuracy = {:0.2f}%.'.format(accuracy))
    print('[INFO] Classification_report :\n',classification_report(test_labels,predictions))
    print('[INFO] Confusion_Matrix : \n')
    plot_confusion_catrix(Confusion_Matrix)

# %% [markdown]
# ### DF_CH_GCM

# %%
num_df = 0
List_DF,_ = path_build(PATH_DATA_CSV)
print("Data Features Study : ",List_DF[num_df][0])
X,y = split_data(List_DF[num_df][1])
print(X.shape, len(y))
# Out:
# Data Features Study :  DF_CH_GCM.csv
# (500, 17) 500

# %%
correlation_matrix  = X.corr(method='pearson')#
plt.figure(figsize=(30, 30))
sb.heatmap(correlation_matrix , annot=True)
plt.show()

# %%
correlation_matrix .style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_817c8_row0_col0,#T_817c8_row0_col4,#T_817c8_row0_col8,#T_817c8_row1_col1,#T_817c8_row2_col2,#T_817c8_row2_col6,#T_817c8_row3_col3,#T_817c8_row4_col0,#T_817c8_row4_col4,#T_817c8_row4_col8,#T_817c8_row5_col5,#T_817c8_row5_col9,#T_817c8_row6_col2,#T_817c8_row6_col6,#T_817c8_row6_col10,#T_817c8_row7_col7,#T_817c8_row7_col11,#T_817c8_row8_col0,#T_817c8_row8_col4,#T_817c8_row8_col8,#T_817c8_row9_col5,#T_817c8_row9_col9,#T_817c8_row10_col6,#T_817c8_row10_col10,#T_817c8_row11_col7,#T_817c8_row11_col11,#T_817c8_row12_col12,#T_817c8_row13_col13,#T_817c8_row14_col14,#T_817c8_row15_col15,#T_817c8_row16_col16{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_817c8_row0_col1,#T_817c8_row4_col1,#T_817c8_row8_col1{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_817c8_row0_col2,#T_817c8_row0_col10,#T_817c8_row4_col2,#T_817c8_row4_col10,#T_817c8_row8_col2,#T_817c8_row8_col10,#T_817c8_row15_col14{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_817c8_row0_col3,#T_817c8_row4_col3,#T_817c8_row8_col3{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }#T_817c8_row0_col5,#T_817c8_row4_col5,#T_817c8_row6_col12,#T_817c8_row8_col5{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_817c8_row0_col6,#T_817c8_row4_col6,#T_817c8_row8_col6{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_817c8_row0_col7,#T_817c8_row4_col7,#T_817c8_row8_col7,#T_817c8_row13_col15{
#             background-color:  #f59f80;
#             color:  #000000;
#         }#T_817c8_row0_col9,#T_817c8_row4_col9,#T_817c8_row8_col9,#T_817c8_row12_col6{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_817c8_row0_col11,#T_817c8_row4_col11,#T_817c8_row6_col15,#T_817c8_row8_col11{
#             background-color:  #f6a586;
#             color:  #000000;
#         }#T_817c8_row0_col12,#T_817c8_row4_col12,#T_817c8_row8_col12{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_817c8_row0_col13,#T_817c8_row4_col13,#T_817c8_row8_col13{
#             background-color:  #f5a081;
#             color:  #000000;
#         }#T_817c8_row0_col14,#T_817c8_row4_col14,#T_817c8_row8_col14{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_817c8_row0_col15,#T_817c8_row4_col15,#T_817c8_row8_col15{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_817c8_row0_col16,#T_817c8_row4_col16,#T_817c8_row8_col16{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_817c8_row1_col0,#T_817c8_row1_col4,#T_817c8_row1_col8{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_817c8_row1_col2,#T_817c8_row1_col10{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_817c8_row1_col3{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_817c8_row1_col5,#T_817c8_row2_col10,#T_817c8_row3_col7,#T_817c8_row5_col1,#T_817c8_row7_col3,#T_817c8_row10_col2{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_817c8_row1_col6{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_817c8_row1_col7,#T_817c8_row12_col0,#T_817c8_row12_col4,#T_817c8_row12_col8{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_817c8_row1_col9,#T_817c8_row3_col11,#T_817c8_row9_col1,#T_817c8_row11_col3{
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }#T_817c8_row1_col11,#T_817c8_row2_col0,#T_817c8_row2_col4,#T_817c8_row2_col8{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_817c8_row1_col12,#T_817c8_row5_col12{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_817c8_row1_col13,#T_817c8_row5_col13{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_817c8_row1_col14{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_817c8_row1_col15,#T_817c8_row15_col5{
#             background-color:  #f6a385;
#             color:  #000000;
#         }#T_817c8_row1_col16,#T_817c8_row6_col5,#T_817c8_row9_col2,#T_817c8_row9_col10{
#             background-color:  #e9785d;
#             color:  #000000;
#         }#T_817c8_row2_col1,#T_817c8_row5_col6,#T_817c8_row10_col1{
#             background-color:  #e57058;
#             color:  #000000;
#         }#T_817c8_row2_col3,#T_817c8_row2_col7,#T_817c8_row2_col11,#T_817c8_row3_col2,#T_817c8_row3_col6,#T_817c8_row3_col10,#T_817c8_row6_col3,#T_817c8_row6_col7,#T_817c8_row6_col11,#T_817c8_row10_col3,#T_817c8_row10_col7,#T_817c8_row10_col11,#T_817c8_row11_col1,#T_817c8_row11_col5,#T_817c8_row11_col9,#T_817c8_row11_col16,#T_817c8_row12_col13,#T_817c8_row12_col15,#T_817c8_row13_col12,#T_817c8_row13_col14,#T_817c8_row14_col0,#T_817c8_row14_col4,#T_817c8_row14_col8{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_817c8_row2_col5,#T_817c8_row10_col5,#T_817c8_row15_col16,#T_817c8_row16_col1{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_817c8_row2_col9,#T_817c8_row16_col9,#T_817c8_row16_col15{
#             background-color:  #ec8165;
#             color:  #000000;
#         }#T_817c8_row2_col12,#T_817c8_row11_col13{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_817c8_row2_col13,#T_817c8_row7_col12{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_817c8_row2_col14{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_817c8_row2_col15,#T_817c8_row9_col15,#T_817c8_row10_col15{
#             background-color:  #f7a688;
#             color:  #000000;
#         }#T_817c8_row2_col16,#T_817c8_row10_col16{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_817c8_row3_col0,#T_817c8_row3_col4,#T_817c8_row3_col8{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_817c8_row3_col1,#T_817c8_row7_col9,#T_817c8_row11_col6,#T_817c8_row11_col10{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_817c8_row3_col5{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_817c8_row3_col9{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_817c8_row3_col12{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_817c8_row3_col13,#T_817c8_row13_col7{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_817c8_row3_col14,#T_817c8_row12_col10,#T_817c8_row13_col11{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_817c8_row3_col15,#T_817c8_row5_col7{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_817c8_row3_col16,#T_817c8_row7_col2,#T_817c8_row7_col5,#T_817c8_row7_col16{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_817c8_row5_col0,#T_817c8_row5_col4,#T_817c8_row5_col8,#T_817c8_row15_col0,#T_817c8_row15_col4,#T_817c8_row15_col8{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_817c8_row5_col2,#T_817c8_row5_col10{
#             background-color:  #e7745b;
#             color:  #000000;
#         }#T_817c8_row5_col3{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_817c8_row5_col11,#T_817c8_row6_col0,#T_817c8_row6_col4,#T_817c8_row6_col8,#T_817c8_row10_col0,#T_817c8_row10_col4,#T_817c8_row10_col8,#T_817c8_row11_col15{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_817c8_row5_col14,#T_817c8_row16_col12{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_817c8_row5_col15{
#             background-color:  #f7a889;
#             color:  #000000;
#         }#T_817c8_row5_col16,#T_817c8_row10_col9{

# %%
correlated_features = set()
for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
len(correlated_features)

# %%
X.drop(labels=correlated_features, axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_randomrorestClassifier(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# [INFO] Applying took 20.45 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.16 %.
# [INFO] Accuracy = 0.84%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        22
#            1       0.96      0.92      0.94        25
#            2       0.66      0.73      0.69        26
#            3       0.93      1.00      0.97        28
#            4       0.72      0.54      0.62        24
#
#     accuracy                           0.84       125
#    macro avg       0.84      0.84      0.83       125
# weighted avg       0.84      0.84      0.83       125
#
# [INFO] Confusion_Matrix :

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    randomizedsearch = hyperparameter_tuning_MultiLayerPerceptron(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# [INFO] Applying took 148.26 seconds
# [INFO] Model Performance
# [INFO] Average Error: 0.28 %.
# [INFO] Accuracy = 0.72%.
# [INFO] Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        22
#            1       0.77      0.96      0.86        25
#            2       0.69      0.42      0.52        26
#            3       0.72      0.75      0.74        28
#            4       0.50      0.50      0.50        24
#
#     accuracy                           0.72       125
#    macro avg       0.71      0.73      0.71       125
# weighted avg       0.71      0.72      0.71       125
#
# [INFO] Confusion_Matrix :
