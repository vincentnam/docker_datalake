# %% [markdown]
# ### Importation des bibliothèques nécessaire

# %%
import cv2 
import os
import time
import descriptors
import numpy as np
import pandas as pd

# %% [markdown]
# ### Instanciation d'objet descriptor

# %%
d = descriptors.Descriptors(nbr_class = 5 , nbr_images =500)

# %% [markdown]
# ### Récupération des path

# %%
(Tempo,_) = os.path.split(os.getcwd())
PATH_PROJECT,DEV = os.path.split(Tempo)
PATH_DEV = os.path.join(PATH_PROJECT,'Dev')
PATH_DATA = os.path.join(PATH_PROJECT,'Data')
PATH_DATA_IMAGES = os.path.join(PATH_DATA,'Data Images')
DATA_CBIRH_5_500 = os.path.join(PATH_DATA_IMAGES,'DATA_CBIRH_5_500')
PATH_DATA_CSV = os.path.join(os.path.join(PATH_DATA,'Data Descriptors'),'Data Feautures_5_500/All descriptors')
LIST_CLASS = os.listdir(DATA_CBIRH_5_500)

PATH_LIST =[]
for f in LIST_CLASS :
    PATH_LIST.append(os.path.join(DATA_CBIRH_5_500,f))

# %% [markdown]
# ### Création des data features

# %%
data = d.create_data_feautures_all_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_ALL_0.csv')
# Out:
# [INFO] Applying took 691.01 seconds

# %%
### Afficher 10  premiers lignes de dataframe
data.head(10)
# Out:
#         0         1          2           3         4       5      6    \
# 0  car_0000  0.390625   2.339600   90.595078  3.454745  19.031  0.873
# 1  car_0001  0.390625   0.698975    7.254659  3.963114  11.838  0.929
# 2  car_0002  0.390625   0.472412    7.921624  4.256070  13.398  0.920
# 3  car_0003  0.390625   1.792725   27.163445  3.309397  12.535  0.931
# 4  car_0004  0.390625   8.144287   81.030678  1.706143   8.368  0.944
# 5  car_0005  0.390625  17.105213  229.738831  1.329271  13.570  0.923
# 6  car_0006  0.390625   1.331787   21.182627  3.467867  14.716  0.894
# 7  car_0007  0.390625   5.792725   62.159546  2.179447  10.036  0.871
# 8  car_0008  0.390625   1.714600   19.618683  3.237497  16.275  0.872
# 9  car_0009  0.390625   1.214600   12.120042  3.504383  13.530  0.908
#
#         7      8      9    ...        503        504       505       506  \
# 0  1004.124  0.144  0.013  ...  17.862069  13.206897  2.871852  7.653811
# 1   677.696  0.325  0.039  ...   4.200000   5.600000  2.924580  6.281702
# 2   611.496  0.219  0.019  ...   8.074074  17.370370  2.987831  7.698294
# 3   605.099  0.243  0.019  ...  21.666667  13.250000  2.923186  7.516076
# 4   416.068  0.346  0.037  ...   5.357143   3.500000  2.773994  7.137877
# 5   719.741  0.304  0.037  ...  22.916667   3.666667  2.847752  6.316822
# 6   768.254  0.215  0.020  ...  13.047619  18.238095  2.609496  6.565788
# 7   485.075  0.324  0.074  ...   1.363636   1.454545  2.210854  4.796127
# 8  1008.540  0.215  0.018  ...   4.684211   6.947368  2.773340  7.631753
# 9   618.653  0.200  0.018  ...  14.000000  14.421053  2.851666  7.303109
#
#          507        508        509        510        511  512
# 0  11.358986  10.851764 -21.991393 -15.296077 -22.375066    0
# 1  11.730544  10.893916  22.249823 -15.438661  22.575870    0
# 2  10.091532   9.952198  20.561719 -13.822624 -19.989072    0
# 3   9.881152   9.687219  21.043052 -13.475810 -19.471560    0
# 4  10.588063  10.354124  20.826359 -13.923390 -21.965299    0
# 5  10.358580  11.555399  22.633513  14.728115  22.696903    0
# 6   9.718423   8.954706  18.451744 -12.242018 -18.432264    0
# 7   7.589151   7.628627  16.192683  10.027116 -15.240202    0
# 8   9.675204   9.816578 -19.635657 -13.866872 -19.834194    0
# 9   9.181791   9.445266 -19.090787 -13.343027 -18.811853    0
#
# [10 rows x 513 columns]
