# %%
### Importation des bibliothèques nécessaire

# %%
import cv2 
import os
import time
import descriptors
import numpy as np
import pandas as pd

# %%
d = descriptors.Descriptors(nbr_class = 5 , nbr_images =500)

# %%
### Récupération des paths
(Tempo,_) = os.path.split(os.getcwd())
PATH_PROJECT,DEV = os.path.split(Tempo)
PATH_DEV = os.path.join(PATH_PROJECT,'Dev')
PATH_DATA = os.path.join(PATH_PROJECT,'Data')
PATH_DATA_IMAGES = os.path.join(PATH_DATA,'Data Images')
DATA_CBIRH_5_500 = os.path.join(PATH_DATA_IMAGES,'DATA_CBIRH_5_500')
PATH_DATA_CSV = os.path.join(os.path.join(PATH_DATA,'Data Descriptors'),'Data Feautures_5_500/All descriptors')
LIST_CLASS = os.listdir(DATA_CBIRH_5_500)
PATH_LIST =[]

for f in ['fruit', 'car', 'dog', 'person','cat'] :
    PATH_LIST.append(os.path.join(DATA_CBIRH_5_500,f))

# %% [markdown]
# ## Creation data features

# %%
data = d.create_data_feautures_all_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_ALL_resise.csv')
# Out:
# [INFO] Applying took 947.38 seconds

# %%
data.head(10)
# Out:
#           0         1          2           3         4      5      6    \
# 0  fruit_0000  0.390625  24.753662  228.664688  0.655818  3.738  0.973
# 1  fruit_0001  0.390625  11.261475  120.360558  1.402632  5.714  0.982
# 2  fruit_0002  0.390625  26.378662  246.016937  0.803683  4.748  0.944
# 3  fruit_0003  0.390625  27.331787  240.592346  0.593292  3.999  0.980
# 4  fruit_0004  0.390625  12.925537  159.098663  1.472703  6.703  0.974
# 5  fruit_0005  0.390625  17.917725  236.621689  1.477988  6.521  0.974
# 6  fruit_0006  0.390625  37.370850  250.898529  0.111902  3.923  0.981
# 7  fruit_0007  0.390625  31.753662  246.809433  0.375123  2.799  0.986
# 8  fruit_0008  0.390625  25.331787  241.556564  0.799976  4.261  0.972
# 9  fruit_0009  0.390625  28.863037  248.862244  0.686021  7.611  0.975
#
#        7      8      9    ...           503        504       505       506  \
# 0  135.925  0.479  0.207  ...  2.857143e-01   2.857143  3.136762  8.978052
# 1  327.895  0.428  0.126  ...  0.000000e+00   0.250000  2.446304  7.004116
# 2  225.034  0.547  0.301  ...  0.000000e+00   1.750000  3.162789  9.116823
# 3  161.597  0.500  0.198  ...  3.333333e-01   0.333333  2.950030  8.059025
# 4  337.205  0.341  0.123  ...  8.881784e-16   2.500000  2.682110  7.484031
# 5  186.313  0.306  0.133  ...  3.909091e+00   4.545455  2.915560  8.060132
# 6  120.259  0.493  0.248  ... -1.387779e-17   0.800000  3.119066  8.806388
# 7   54.296  0.550  0.161  ...  0.000000e+00   3.000000  3.178485  9.852212
# 8  163.187  0.484  0.297  ...  0.000000e+00   0.000000  3.129331  9.082372
# 9  458.829  0.510  0.398  ...  1.536364e+01  23.909091  2.757507  7.112633
#
#          507        508        509        510        511  512
# 0  13.010840  11.523092  24.663274 -16.075241  23.793987    0
# 1  10.154315  10.293925 -20.848732  14.177077  20.571465    0
# 2  12.829299  12.367674 -25.045003 -16.965909 -25.224386    0
# 3  11.186873   9.959668  21.116559  14.715713  20.548240    0
# 4  10.943719   9.266281 -19.781383  13.013908 -19.406899    0
# 5  10.889912   9.638492  20.252332 -13.888083 -19.951112    0
# 6  12.223419  11.199093  23.337773 -15.693950  22.943021    0
# 7  13.142839  13.377041 -26.637041 -18.310354  28.419713    0
# 8  12.528485  11.433140  24.146722 -16.041226 -23.421517    0
# 9  11.114373  11.588995  22.947425 -16.131499 -23.697890    0
#
# [10 rows x 513 columns]
