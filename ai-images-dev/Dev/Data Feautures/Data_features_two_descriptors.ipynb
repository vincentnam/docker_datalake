# %% [markdown]
# ### Importation des bibliothèques nécessaire

# %%
import cv2 
import os
import time
import numpy as np
import pandas as pd

# %% [markdown]
# ### Instanciation d'objet descriptors

# %%
import descriptors

d = descriptors.Descriptors(nbr_class = 5 , nbr_images =500)

# %%
### Récupération des paths

# %%
(Tempo,_) = os.path.split(os.getcwd())
PATH_PROJECT,DEV = os.path.split(Tempo)
PATH_DEV = os.path.join(PATH_PROJECT,'Dev')
PATH_DATA = os.path.join(PATH_PROJECT,'Data')
PATH_DATA_IMAGES = os.path.join(PATH_DATA,'Data Images')
DATA_CBIRH_5_500 = os.path.join(PATH_DATA_IMAGES,'DATA_CBIRH_5_500')
PATH_DATA_CSV = os.path.join(os.path.join(os.path.join(PATH_DATA,'Data Descriptors'),'Data Feautures_5_500'),'Two descriptors')
LIST_CLASS = os.listdir(DATA_CBIRH_5_500)

PATH_LIST =[]
for f in LIST_CLASS :
    PATH_LIST.append(os.path.join(DATA_CBIRH_5_500,f))

# %% [markdown]
# ## Create data features GCM_DCD

# %%
columns = ['name_image','dissimilarity','correlation', 'contrast','homogeneity','energy',
           'l_1','u_1','v_1','percent_1','l_2','u_2','v_2','percent_2','l_3','u_3','v_3','percent_3','label']
data = d.create_data_feautures_2_descriptors(PATH_LIST,columns,PATH_DATA_CSV, 'DF_DCD_GCM.csv',d.DOMINANT_COLOR_DESCRIPTOR, d.DESCRIPTOR_TEXTURE_MATRIX_COCCURRENCE)

data.head(10)
# Out:
# [INFO] Applying took 135.69 seconds
#   name_image  dissimilarity  correlation    contrast  homogeneity      energy  \
# 0   car_0000      43.511002    96.403000  138.470001        25.97  200.339996
# 1   car_0001      69.322998    97.373001  139.403000        34.50  177.906006
# 2   car_0002      34.301998    96.019997  138.886993        17.94  106.942001
# 3   car_0003     116.272003    96.554001  140.572006        44.68  203.716995
# 4   car_0004      26.698999    96.365997  136.319000        20.34  111.046997
# 5   car_0005      28.861000    96.410004  136.457993        42.95  196.817993
# 6   car_0006      29.788000   100.997002  138.921997        42.00   90.445999
# 7   car_0007      11.272000    99.447998  137.970993        73.64  171.593002
# 8   car_0008      52.985001   109.586998  138.563004        35.16  122.057999
# 9   car_0009     196.029999    94.810997  127.955002        25.29   56.234001
#
# ...

# %% [markdown]
# ## Create data features CH_TH

# %%
columns = ['name_img','mean_color_1', 'var_color_1', 'kurtosis_color_1', 'entropy_color_1',
                        'mean_color_2', 'var_color_2', 'kurtosis_color_2', 'entropy_color_2',
                        'mean_color_3', 'var_color_3', 'kurtosis_color_3', 'entropy_color_3',
                     'mean_color_gray', 'var_color_gray', 'kurtosis_color_gray', 'entropy_color_gray','label']
data = d.create_data_feautures_2_descriptors(PATH_LIST,columns,PATH_DATA_CSV, 'DF_CH_TH.csv',d.descriprot_color_hitogramme, d.descriprot_texture_hitogramme)
data.head(10)
# Out:
# [INFO] Applying took 11.99 seconds
#    name_img  mean_color_1  var_color_1  kurtosis_color_1  entropy_color_1  \
# 0  car_0000      1.171875    18.072021        151.657410         3.898141
# 1  car_0001      1.171875     4.509521          7.527699         4.281093
# 2  car_0002      1.171875     2.056396          2.822962         4.810859
# 3  car_0003      1.171875     8.017334         13.447430         3.932332
# 4  car_0004      1.171875    20.282959         17.814667         2.906861
# 5  car_0005      1.171875   147.728363        229.521957         1.414230
# 6  car_0006      1.171875     4.462646          4.172307         4.254196
# 7  car_0007      1.171875    46.931396         53.690681         2.354585
# 8  car_0008      1.171875     4.118896          2.939957         4.296141
# 9  car_0009      1.171875     6.173584          4.108876         3.956931
#
#    mean_color_2  var_color_2  kurtosis_color_2  entropy_color_2  mean_color_3  \
# ...

# %% [markdown]
# ## Create data features CH_GCM

# %%
columns = ['name_img','mean_color_1', 'var_color_1', 'kurtosis_color_1', 'entropy_color_1',
                        'mean_color_2', 'var_color_2', 'kurtosis_color_2', 'entropy_color_2',
                        'mean_color_3', 'var_color_3', 'kurtosis_color_3', 'entropy_color_3',
                     'dissimilarity','correlation', 'contrast','homogeneity','energy','label']

data = d.create_data_feautures_2_descriptors(PATH_LIST,columns,PATH_DATA_CSV, 'DF_CH_GCM.csv',d.descriprot_color_hitogramme, d.DESCRIPTOR_TEXTURE_MATRIX_COCCURRENCE)
data.head(10)
# Out:
# [INFO] Applying took 16.06 seconds
#    name_img  mean_color_1  var_color_1  kurtosis_color_1  entropy_color_1  \
# 0  car_0000      1.171875    18.072021        151.657410         3.898141
# 1  car_0001      1.171875     4.509521          7.527699         4.281093
# 2  car_0002      1.171875     2.056396          2.822962         4.810859
# 3  car_0003      1.171875     8.017334         13.447430         3.932332
# 4  car_0004      1.171875    20.282959         17.814667         2.906861
# 5  car_0005      1.171875   147.728363        229.521957         1.414230
# 6  car_0006      1.171875     4.462646          4.172307         4.254196
# 7  car_0007      1.171875    46.931396         53.690681         2.354585
# 8  car_0008      1.171875     4.118896          2.939957         4.296141
# 9  car_0009      1.171875     6.173584          4.108876         3.956931
#
#    mean_color_2  var_color_2  kurtosis_color_2  entropy_color_2  mean_color_3  \
# ...

# %% [markdown]
# ## Create data features DCD_TH

# %%
columns = ['name_img','l_1','u_1','v_1','percent_1','l_2','u_2','v_2','percent_2','l_3','u_3','v_3','percent_3',
                     'mean_color_gray', 'var_color_gray', 'kurtosis_color_gray', 'entropy_color_gray','label']
data = d.create_data_feautures_2_descriptors(PATH_LIST,columns,PATH_DATA_CSV, 'DF_DCD_TH.csv',d.DOMINANT_COLOR_DESCRIPTOR, d.descriprot_texture_hitogramme)
data.head(10)
# Out:
# [INFO] Applying took 353.74 seconds
#    name_img         l_1         u_1         v_1  percent_1         l_2  \
# 0  car_0000   43.666000   96.384003  138.453003      26.07  200.488998
# 1  car_0001  128.880005   96.350998  136.955002      20.91   35.721001
# 2  car_0002  106.942001   95.738998  139.800995      39.29  192.106995
# 3  car_0003  116.272003   96.554001  140.572006      44.68   28.936001
# 4  car_0004  191.686005   94.426003  127.945000      36.42   26.698999
# 5  car_0005   28.861000   96.410004  136.457993      42.95  196.817993
# 6  car_0006   29.788000  100.997002  138.921997      42.00  171.623001
# 7  car_0007  171.593002   99.525002  137.695999       6.51   11.275000
# 8  car_0008   52.985001  109.586998  138.563004      35.16  196.054993
# 9  car_0009   56.234001  100.059998  139.623001      39.54  196.029999
#
#           u_2         v_2  percent_2         l_3         u_3         v_3  \
# 0  101.236000  158.399002      34.06  123.359001   95.939003  143.794998
# ...

# %% [markdown]
# ## Create data features HM_TH

# %%
columns = ['name_img','m_1', 'm_2', 'm_3', 'm_4', 'm_5', 'm_6', 'm_7',
                     'mean_color_gray', 'var_color_gray', 'kurtosis_color_gray', 'entropy_color_gray','label']
data = d.create_data_feautures_2_descriptors(PATH_LIST,columns,PATH_DATA_CSV, 'DF_HM_TH.csv',d.descriprot_moments_Hu, d.descriprot_texture_hitogramme)
data.head(10)
# Out:
# [INFO] Applying took 9.61 seconds
#    name_img       m_1       m_2        m_3        m_4        m_5        m_6  \
# 0  car_0000  2.871852  7.653811  11.358986  10.851764 -21.991393 -15.296077
# 1  car_0001  2.924580  6.281702  11.730544  10.893916  22.249823 -15.438661
# 2  car_0002  2.987831  7.698294  10.091532   9.952198  20.561719 -13.822624
# 3  car_0003  2.923186  7.516076   9.881152   9.687219  21.043052 -13.475810
# 4  car_0004  2.773994  7.137877  10.588063  10.354124  20.826359 -13.923390
# 5  car_0005  2.847752  6.316822  10.358580  11.555399  22.633513  14.728115
# 6  car_0006  2.609496  6.565788   9.718423   8.954706  18.451744 -12.242018
# 7  car_0007  2.210854  4.796127   7.589151   7.628627  16.192683  10.027116
# 8  car_0008  2.773340  7.631753   9.675204   9.816578 -19.635657 -13.866872
# 9  car_0009  2.851666  7.303109   9.181791   9.445266 -19.090787 -13.343027
#
#          m_7  mean_color_gray  var_color_gray  kurtosis_color_gray  \
# ...

# %% [markdown]
# ## Create data features HM_CH

# %%
columns = ['name_img','m_1', 'm_2', 'm_3', 'm_4', 'm_5', 'm_6', 'm_7',
                     'mean_color_1', 'var_color_1', 'kurtosis_color_1', 'entropy_color_1',
                        'mean_color_2', 'var_color_2', 'kurtosis_color_2', 'entropy_color_2',
                        'mean_color_3', 'var_color_3', 'kurtosis_color_3', 'entropy_color_3','label']
data = d.create_data_feautures_2_descriptors(PATH_LIST,columns,PATH_DATA_CSV, 'DF_HM_CH.csv',d.descriprot_moments_Hu, d.descriprot_color_hitogramme)
data.head(10)
# Out:
# [INFO] Applying took 12.04 seconds
#    name_img       m_1       m_2        m_3        m_4        m_5        m_6  \
# 0  car_0000  2.871852  7.653811  11.358986  10.851764 -21.991393 -15.296077
# 1  car_0001  2.924580  6.281702  11.730544  10.893916  22.249823 -15.438661
# 2  car_0002  2.987831  7.698294  10.091532   9.952198  20.561719 -13.822624
# 3  car_0003  2.923186  7.516076   9.881152   9.687219  21.043052 -13.475810
# 4  car_0004  2.773994  7.137877  10.588063  10.354124  20.826359 -13.923390
# 5  car_0005  2.847752  6.316822  10.358580  11.555399  22.633513  14.728115
# 6  car_0006  2.609496  6.565788   9.718423   8.954706  18.451744 -12.242018
# 7  car_0007  2.210854  4.796127   7.589151   7.628627  16.192683  10.027116
# 8  car_0008  2.773340  7.631753   9.675204   9.816578 -19.635657 -13.866872
# 9  car_0009  2.851666  7.303109   9.181791   9.445266 -19.090787 -13.343027
#
#          m_7  mean_color_1  var_color_1  ...  entropy_color_1  mean_color_2  \
# ...

# %% [markdown]
# ## Create data features HM_GCM

# %%
columns = ['name_img','m_1', 'm_2', 'm_3', 'm_4', 'm_5', 'm_6', 'm_7',
                     'dissimilarity','correlation', 'contrast','homogeneity','energy','label']

data = d.create_data_feautures_2_descriptors(PATH_LIST,columns,PATH_DATA_CSV, 'DF_HM_GCM.csv',d.descriprot_moments_Hu, d.DESCRIPTOR_TEXTURE_MATRIX_COCCURRENCE)
data.head(10)
# Out:
# [INFO] Applying took 10.36 seconds
#    name_img       m_1       m_2        m_3        m_4        m_5        m_6  \
# 0  car_0000  2.871852  7.653811  11.358986  10.851764 -21.991393 -15.296077
# 1  car_0001  2.924580  6.281702  11.730544  10.893916  22.249823 -15.438661
# 2  car_0002  2.987831  7.698294  10.091532   9.952198  20.561719 -13.822624
# 3  car_0003  2.923186  7.516076   9.881152   9.687219  21.043052 -13.475810
# 4  car_0004  2.773994  7.137877  10.588063  10.354124  20.826359 -13.923390
# 5  car_0005  2.847752  6.316822  10.358580  11.555399  22.633513  14.728115
# 6  car_0006  2.609496  6.565788   9.718423   8.954706  18.451744 -12.242018
# 7  car_0007  2.210854  4.796127   7.589151   7.628627  16.192683  10.027116
# 8  car_0008  2.773340  7.631753   9.675204   9.816578 -19.635657 -13.866872
# 9  car_0009  2.851666  7.303109   9.181791   9.445266 -19.090787 -13.343027
#
#          m_7  dissimilarity  correlation  contrast  homogeneity  energy label
# ...

# %% [markdown]
# ## Create data features HM_DCD

# %%
columns = ['name_img','m_1', 'm_2', 'm_3', 'm_4', 'm_5', 'm_6', 'm_7',
                     'l_1','u_1','v_1','percent_1','l_2','u_2','v_2','percent_2','l_3','u_3','v_3','percent_3','label']

data = d.create_data_feautures_2_descriptors(PATH_LIST,columns,PATH_DATA_CSV, 'DF_HM_DCD.csv',d.descriprot_moments_Hu, d.DOMINANT_COLOR_DESCRIPTOR)
data.head(10)
# Out:
# [INFO] Applying took 133.24 seconds
#    name_img       m_1       m_2        m_3        m_4        m_5        m_6  \
# 0  car_0000  2.871852  7.653811  11.358986  10.851764 -21.991393 -15.296077
# 1  car_0001  2.924580  6.281702  11.730544  10.893916  22.249823 -15.438661
# 2  car_0002  2.987831  7.698294  10.091532   9.952198  20.561719 -13.822624
# 3  car_0003  2.923186  7.516076   9.881152   9.687219  21.043052 -13.475810
# 4  car_0004  2.773994  7.137877  10.588063  10.354124  20.826359 -13.923390
# 5  car_0005  2.847752  6.316822  10.358580  11.555399  22.633513  14.728115
# 6  car_0006  2.609496  6.565788   9.718423   8.954706  18.451744 -12.242018
# 7  car_0007  2.210854  4.796127   7.589151   7.628627  16.192683  10.027116
# 8  car_0008  2.773340  7.631753   9.675204   9.816578 -19.635657 -13.866872
# 9  car_0009  2.851666  7.303109   9.181791   9.445266 -19.090787 -13.343027
#
#          m_7         l_1         u_1  ...  percent_1         l_2         u_2  \
# ...

# %% [markdown]
# ## Create data features SIFT_DCD

# %%
data = d.create_data_feautures_2_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_SIFT_DCD.csv',d.descriprot_sift, d.DOMINANT_COLOR_DESCRIPTOR)
data.head(10)
# Out:
# [INFO] Applying took 223.95 seconds
#         0          1          2           3             4          5    \
# 0  car_0000  53.651144  40.754548  194.399504  9.331319e+06  28.062500
# 1  car_0001  52.563964  54.179029  181.857180  4.431832e+06  27.384615
# 2  car_0002  62.204416  50.358542  205.367225  6.847339e+06  15.631579
# 3  car_0003  46.244761  60.085096  190.895045  9.319315e+06  28.730769
# 4  car_0004  43.188532  45.340824  229.452406  1.564511e+07  30.571429
# 5  car_0005  51.776378  58.019215  164.626059  9.180584e+05  15.000000
# 6  car_0006  56.834020  39.472514  236.172343  1.105371e+06  19.785714
# 7  car_0007  38.459843  46.711495  251.745999  6.458485e+06  25.461538
# 8  car_0008  43.253672  40.076405  153.950867  8.852681e+06  10.357143
# 9  car_0009  54.626190  45.057248  207.182751  1.204545e+07  25.421053
#
#          6          7          8          9    ...    400         401  \
# 0  22.843750  25.812500  25.343750  17.062500  ...  25.97  200.339996
# ...

# %% [markdown]
# ## Create data features SIFT_GCM

# %%
data = d.create_data_feautures_2_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_SIFT_GCM.csv',d.descriprot_sift, d.DESCRIPTOR_TEXTURE_MATRIX_COCCURRENCE)
data.head(10)
# Out:
# [INFO] Applying took 108.03 seconds
#         0          1          2           3             4          5    \
# 0  car_0000  53.651144  40.754548  194.399504  9.331319e+06  28.062500
# 1  car_0001  52.563964  54.179029  181.857180  4.431832e+06  27.384615
# 2  car_0002  62.204416  50.358542  205.367225  6.847339e+06  15.631579
# 3  car_0003  46.244761  60.085096  190.895045  9.319315e+06  28.730769
# 4  car_0004  43.188532  45.340824  229.452406  1.564511e+07  30.571429
# 5  car_0005  51.776378  58.019215  164.626059  9.180584e+05  15.000000
# 6  car_0006  56.834020  39.472514  236.172343  1.105371e+06  19.785714
# 7  car_0007  38.459843  46.711495  251.745999  6.458485e+06  25.461538
# 8  car_0008  43.253672  40.076405  153.950867  8.852681e+06  10.357143
# 9  car_0009  54.626190  45.057248  207.182751  1.204545e+07  25.421053
#
#          6          7          8          9    ...        393        394  \
# 0  22.843750  25.812500  25.343750  17.062500  ...  31.413793  19.689655
# ...

# %% [markdown]
# ## Create data features SIFT_CH

# %%
data = d.create_data_feautures_2_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_SIFT_CH.csv',d.descriprot_sift, d.descriprot_color_hitogramme)
data.head(10)
# Out:
# [INFO] Applying took 107.47 seconds
#         0          1          2           3             4          5    \
# 0  car_0000  53.651144  40.754548  194.399504  9.331319e+06  28.062500
# 1  car_0001  52.563964  54.179029  181.857180  4.431832e+06  27.384615
# 2  car_0002  62.204416  50.358542  205.367225  6.847339e+06  15.631579
# 3  car_0003  46.244761  60.085096  190.895045  9.319315e+06  28.730769
# 4  car_0004  43.188532  45.340824  229.452406  1.564511e+07  30.571429
# 5  car_0005  51.776378  58.019215  164.626059  9.180584e+05  15.000000
# 6  car_0006  56.834020  39.472514  236.172343  1.105371e+06  19.785714
# 7  car_0007  38.459843  46.711495  251.745999  6.458485e+06  25.461538
# 8  car_0008  43.253672  40.076405  153.950867  8.852681e+06  10.357143
# 9  car_0009  54.626190  45.057248  207.182751  1.204545e+07  25.421053
#
#          6          7          8          9    ...       400       401  \
# 0  22.843750  25.812500  25.343750  17.062500  ...  3.898141  1.171875
# ...

# %% [markdown]
# ## Create data features SIFT_TH

# %%
data = d.create_data_feautures_2_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_SIFT_TH.csv',d.descriprot_sift, d.descriprot_texture_hitogramme)
data.head(10)
# Out:
# [INFO] Applying took 103.74 seconds
#         0          1          2           3             4          5    \
# 0  car_0000  53.651144  40.754548  194.399504  9.331319e+06  28.062500
# 1  car_0001  52.563964  54.179029  181.857180  4.431832e+06  27.384615
# 2  car_0002  62.204416  50.358542  205.367225  6.847339e+06  15.631579
# 3  car_0003  46.244761  60.085096  190.895045  9.319315e+06  28.730769
# 4  car_0004  43.188532  45.340824  229.452406  1.564511e+07  30.571429
# 5  car_0005  51.776378  58.019215  164.626059  9.180584e+05  15.000000
# 6  car_0006  56.834020  39.472514  236.172343  1.105371e+06  19.785714
# 7  car_0007  38.459843  46.711495  251.745999  6.458485e+06  25.461538
# 8  car_0008  43.253672  40.076405  153.950867  8.852681e+06  10.357143
# 9  car_0009  54.626190  45.057248  207.182751  1.204545e+07  25.421053
#
#          6          7          8          9    ...        392        393  \
# 0  22.843750  25.812500  25.343750  17.062500  ...  22.448276  31.413793
# ...

# %% [markdown]
# ## Create data features FG_DCD

# %%
data = d.create_data_feautures_2_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_DCD_FG.csv',d.DOMINANT_COLOR_DESCRIPTOR, d.descriprot_filter_gabor)
data.head(10)
# Out:
# [INFO] Applying took 1534.63 seconds
#          0           1           2           3      4           5   \
# 0  car_0000  200.339996  101.227997  158.380005  34.19   43.511002
# 1  car_0001   35.721001   96.996002  138.380997  56.29  197.281006
# 2  car_0002  106.942001   95.738998  139.800995  39.29   34.301998
# 3  car_0003  116.272003   96.554001  140.572006  44.68   28.936001
# 4  car_0004  111.046997   93.112999  127.676003  43.24  191.686005
# 5  car_0005   28.861000   96.410004  136.457993  42.95  196.817993
# 6  car_0006   90.445999  105.377998  143.270996  25.60   29.788000
# 7  car_0007   70.129997  130.983002  146.197006  19.85  171.593002
# 8  car_0008   52.985001  109.586998  138.563004  35.16  196.054993
# 9  car_0009  196.029999   94.810997  127.955002  25.29   56.234001
#
#            6           7      8           9   ...    79    80     81     82  \
# 0   96.403000  138.470001  25.97  123.137001  ...  4934  8722  15918  26504
# ...

# %% [markdown]
# ## Create data features CH_FG

# %%
data = d.create_data_feautures_2_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_CH_FG.csv',d.descriprot_color_hitogramme, d.descriprot_filter_gabor)
data.head(10)
# Out:
# [INFO] Applying took 1485.98 seconds
#          0         1           2           3         4         5           6   \
# 0  car_0000  1.171875   18.072021  151.657410  3.898141  1.171875    5.181396
# 1  car_0001  1.171875    4.509521    7.527699  4.281093  1.171875    4.572021
# 2  car_0002  1.171875    2.056396    2.822962  4.810859  1.171875    2.134521
# 3  car_0003  1.171875    8.017334   13.447430  3.932332  1.171875    8.454834
# 4  car_0004  1.171875   20.282959   17.814667  2.906861  1.171875   15.665771
# 5  car_0005  1.171875  147.728363  229.521957  1.414230  1.171875  114.798569
# 6  car_0006  1.171875    4.462646    4.172307  4.254196  1.171875    2.954834
# 7  car_0007  1.171875   46.931396   53.690681  2.354585  1.171875   28.806396
# 8  car_0008  1.171875    4.118896    2.939957  4.296141  1.171875    4.165771
# 9  car_0009  1.171875    6.173584    4.108876  3.956931  1.171875    7.126709
#
# ...

# %% [markdown]
# ## Create data features HM_FG

# %%
data = d.create_data_feautures_2_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_HM_FG.csv',d.descriprot_moments_Hu, d.descriprot_filter_gabor)
data.head(10)
# Out:
# [INFO] Applying took 648.03 seconds
#          0         1         2          3          4          5          6   \
# 0  car_0000  2.871852  7.653811  11.358986  10.851764 -21.991393 -15.296077
# 1  car_0001  2.924580  6.281702  11.730544  10.893916  22.249823 -15.438661
# 2  car_0002  2.987831  7.698294  10.091532   9.952198  20.561719 -13.822624
# 3  car_0003  2.923186  7.516076   9.881152   9.687219  21.043052 -13.475810
# 4  car_0004  2.773994  7.137877  10.588063  10.354124  20.826359 -13.923390
# 5  car_0005  2.847752  6.316822  10.358580  11.555399  22.633513  14.728115
# 6  car_0006  2.609496  6.565788   9.718423   8.954706  18.451744 -12.242018
# 7  car_0007  2.210854  4.796127   7.589151   7.628627  16.192683  10.027116
# 8  car_0008  2.773340  7.631753   9.675204   9.816578 -19.635657 -13.866872
# 9  car_0009  2.851666  7.303109   9.181791   9.445266 -19.090787 -13.343027
#
#           7       8       9   ...    74    75     76     77   78   79    80  \
# ...

# %% [markdown]
# ## Create data features SIFT_FG

# %%
data = d.create_data_feautures_2_descriptors_without_header(PATH_LIST,PATH_DATA_CSV, 'DF_SIFT_FG.csv',d.descriprot_sift, d.descriprot_filter_gabor)
data.head(10)
# Out:
# [INFO] Applying took 622.61 seconds
#         0          1          2           3             4          5    \
# 0  car_0000  53.651144  40.754548  194.399504  9.331319e+06  28.062500
# 1  car_0001  52.563964  54.179029  181.857180  4.431832e+06  27.384615
# 2  car_0002  62.204416  50.358542  205.367225  6.847339e+06  15.631579
# 3  car_0003  46.244761  60.085096  190.895045  9.319315e+06  28.730769
# 4  car_0004  43.188532  45.340824  229.452406  1.564511e+07  30.571429
# 5  car_0005  51.776378  58.019215  164.626059  9.180584e+05  15.000000
# 6  car_0006  56.834020  39.472514  236.172343  1.105371e+06  19.785714
# 7  car_0007  38.459843  46.711495  251.745999  6.458485e+06  25.461538
# 8  car_0008  43.253672  40.076405  153.950867  8.852681e+06  10.357143
# 9  car_0009  54.626190  45.057248  207.182751  1.204545e+07  25.421053
#
#          6          7          8          9    ...   463   464    465    466  \
# ...
