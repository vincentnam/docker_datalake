# %% [markdown]
# ### Necessary libraries

# %%
#importation des bibliothèques nécessaire
import os
import sys
import time
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import KFold, cross_val_score, RandomizedSearchCV, train_test_split

# %% [markdown]
# ### Paths

# %%
#REPOSITORY PATH OF PROJECT
(Tempo,_) = os.path.split(os.getcwd())
Tempo,_ = os.path.split(Tempo)
PATH_PROJECT,DEV = os.path.split(Tempo)
print(PATH_PROJECT)
PATH_DEV = os.path.join(PATH_PROJECT,'Dev')
PATH_DATA = os.path.join(PATH_PROJECT,'Data')
PATH_DATA_IMAGES = os.path.join(PATH_DATA,'Data Images')
DATA_CBIRH_5_500 = os.path.join(PATH_DATA_IMAGES,'DATA_CBIRH_5_500')
PATH_DATA_CSV = os.path.join(os.path.join(os.path.join(PATH_DATA,'Data Descriptors'),'Data Feautures_5_500'),'Two descriptors')
LIST_CLASS = os.listdir(PATH_DATA_CSV)
print(LIST_CLASS)
# Out:
# C:\Users\yousra.amrani_adm\Adecco\FR_2129564-UNIVPS-NEOCAMPUS - Documents\Datalake\4.Production_Build\CBIRH Project
# ['DF_CH_FG.csv', 'DF_CH_GCM.csv', 'DF_CH_TH.csv', 'DF_DCD_FG.csv', 'DF_DCD_GCM.csv', 'DF_DCD_TH.csv', 'DF_HM_CH.csv', 'DF_HM_DCD.csv', 'DF_HM_FG.csv', 'DF_HM_GCM.csv', 'DF_HM_TH.csv', 'DF_SIFT_CH.csv', 'DF_SIFT_DCD.csv', 'DF_SIFT_FG.csv', 'DF_SIFT_GCM.csv', 'DF_SIFT_TH.csv', 'test1.csv']

# %% [markdown]
# ### Methods

# %%
# build path
def path_build(PATH_DATA_CSV):
    List_DF = []
    List_DF_without_header = []
    for i in os.listdir(PATH_DATA_CSV):
        if i.find('SIFT') !=-1:
            List_DF_without_header.append((i,PATH_DATA_CSV+"/"+i))
        else:
            List_DF.append((i,PATH_DATA_CSV+"/"+i))
    return List_DF,List_DF_without_header

#split data to X,y
def split_data(path):
    DF = pd.read_csv(path)
    DF = DF.iloc[:,1::] 
    y =  DF.label 
    del DF['label']
    X = DF
    return X,y


def split_data_without_head(path):
    DF = pd.read_csv(path)
    DF = DF.iloc[:,1::] 
    y =  y=DF[DF.columns[-1]] 
    del DF[DF.columns[-1]]
    X = DF
    return X,y

#plot confusion matrix
def plot_confusion_catrix(cm):
    
    sb.set(rc={'figure.figsize':(8,8)})
    sb.set(font_scale=1.4)#for label size
    ax = sb.heatmap(cm, annot=True, cmap ='Oranges', cbar=False)
    ax.set_title('Confusion Matrix with labels\n')
    ax.set_xlabel('\nPredicted Label')
    ax.set_ylabel('\nTrue Label ')
    _= ax.xaxis.set_ticklabels(['CAR','DOG','FRUIT','PERSON','CAT'])
    _= ax.yaxis.set_ticklabels(['CAR','DOG','FRUIT','PERSON','CAT'])
    
#evaluate of result
def evaluate(model, test_features, test_labels):
    
    predictions = model.predict(test_features)
    accuracy = accuracy_score(test_labels, predictions)
    errors = 1-accuracy
    Confusion_Matrix = confusion_matrix(test_labels, predictions)
    print('Model Performance')
    print('Average Error: {:0.2f} %.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    print('Classification_report :\n',classification_report(test_labels,predictions))
    print('Confusion_Matrix : \n')
    plot_confusion_catrix(Confusion_Matrix)   


#tuning hyperparameter of model   
def Hyperparameter_tuning_GaussianNB(xtrain,ytrain, X_test, y_test):
    start = time.time()
    nbc = GaussianNB()
    param_grid = {'var_smoothing': np.logspace(0,-9, num=100)}
    kf = KFold(n_splits=5, random_state = 0, shuffle = True)
    randomizedsearch = RandomizedSearchCV(estimator=nbc, param_distributions=param_grid,scoring='accuracy', cv= kf)
    randomizedsearch.fit(xtrain, ytrain)
    end = time.time()
    run_time = end - start
    print("[INFO] Applying took {:.2f} seconds".format(run_time))
    return randomizedsearch

# %% [markdown]
# ### DF_CH_GCM

# %%
num_df = 0
List_DF,_ = path_build(PATH_DATA_CSV)
print("Data Features Study : ",List_DF[num_df][0])
#Data preparation
X,y = split_data(List_DF[num_df][1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
randomizedsearch = Hyperparameter_tuning_GaussianNB(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
# Out:
# Data Features Study :  DF_CH_GCM.csv
# [INFO] Applying took 0.14 seconds

# %%
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# Model Performance
# Average Error: 0.14 %.
# Accuracy = 0.86%.
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       0.96      0.96      0.96        25
#            2       0.64      0.81      0.71        26
#            3       1.00      1.00      1.00        28
#            4       0.75      0.50      0.60        24
#
#     accuracy                           0.86       125
#    macro avg       0.86      0.85      0.85       125
# weighted avg       0.86      0.86      0.85       125
#
# Confusion_Matrix :

# %% [markdown]
# ## DF_CH_TH

# %%
num_df = 1
List_DF,_ = path_build(PATH_DATA_CSV)
print("Data Features Study : ",List_DF[num_df][0])
#Data preparation
X,y = split_data(List_DF[num_df][1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
randomizedsearch = Hyperparameter_tuning_GaussianNB(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
# Out:
# Data Features Study :  DF_CH_TH.csv
# [INFO] Applying took 0.12 seconds

# %%
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# Model Performance
# Average Error: 0.19 %.
# Accuracy = 0.81%.
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        22
#            1       0.96      0.92      0.94        25
#            2       0.55      0.85      0.67        26
#            3       0.97      1.00      0.98        28
#            4       0.75      0.25      0.38        24
#
#     accuracy                           0.81       125
#    macro avg       0.83      0.80      0.78       125
# weighted avg       0.83      0.81      0.79       125
#
# Confusion_Matrix :

# %% [markdown]
# ## DF_DCD_GCM

# %%
num_df = 2
List_DF,_ = path_build(PATH_DATA_CSV)
print("Data Features Study : ",List_DF[num_df][0])
#Data preparation
X,y = split_data(List_DF[num_df][1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
randomizedsearch = Hyperparameter_tuning_GaussianNB(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
# Out:
# Data Features Study :  DF_DCD_GCM.csv
# [INFO] Applying took 0.13 seconds

# %%
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# Model Performance
# Average Error: 0.30 %.
# Accuracy = 0.70%.
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        22
#            1       0.74      0.80      0.77        25
#            2       0.53      0.31      0.39        26
#            3       0.71      0.89      0.79        28
#            4       0.52      0.50      0.51        24
#
#     accuracy                           0.70       125
#    macro avg       0.68      0.70      0.68       125
# weighted avg       0.67      0.70      0.68       125
#
# Confusion_Matrix :

# %% [markdown]
# ## DF_DCD_TH

# %%
num_df = 3
List_DF,_ = path_build(PATH_DATA_CSV)
print("Data Features Study : ",List_DF[num_df][0])
#Data preparation
X,y = split_data(List_DF[num_df][1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
randomizedsearch = Hyperparameter_tuning_GaussianNB(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
# Out:
# Data Features Study :  DF_DCD_TH.csv
# [INFO] Applying took 0.13 seconds

# %%
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# Model Performance
# Average Error: 0.21 %.
# Accuracy = 0.79%.
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       0.95      0.84      0.89        25
#            2       0.53      0.73      0.61        26
#            3       0.93      0.96      0.95        28
#            4       0.67      0.42      0.51        24
#
#     accuracy                           0.79       125
#    macro avg       0.81      0.79      0.79       125
# weighted avg       0.81      0.79      0.79       125
#
# Confusion_Matrix :

# %% [markdown]
# ## DF_SIFT_CH

# %%
num_df = 0
_,List_DF_without_header = path_build(PATH_DATA_CSV)
print("Data Features Study : ",List_DF_without_header[num_df][0])
#Data preparation
X,y = split_data_without_head(List_DF_without_header[num_df][1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
randomizedsearch = Hyperparameter_tuning_GaussianNB(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
# Out:
# Data Features Study :  DF_SIFT_CH.csv
# [INFO] Applying took 0.39 seconds

# %%
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# Model Performance
# Average Error: 0.42 %.
# Accuracy = 0.58%.
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       0.71      0.96      0.81        25
#            2       0.50      0.12      0.19        26
#            3       0.42      0.54      0.47        28
#            4       0.31      0.33      0.32        24
#
#     accuracy                           0.58       125
#    macro avg       0.58      0.59      0.55       125
# weighted avg       0.57      0.58      0.54       125
#
# Confusion_Matrix :

# %% [markdown]
# ## DF_SIFT_DCD

# %%
num_df = 1
_,List_DF_without_header = path_build(PATH_DATA_CSV)
print("Data Features Study : ",List_DF_without_header[num_df][0])
#Data preparation
X,y = split_data_without_head(List_DF_without_header[num_df][1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
randomizedsearch = Hyperparameter_tuning_GaussianNB(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
# Out:
# Data Features Study :  DF_SIFT_DCD.csv
# [INFO] Applying took 0.36 seconds

# %%
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# Model Performance
# Average Error: 0.57 %.
# Accuracy = 0.43%.
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        22
#            1       0.72      0.72      0.72        25
#            2       0.29      0.42      0.34        26
#            3       0.00      0.00      0.00        28
#            4       0.29      0.38      0.33        24
#
#     accuracy                           0.43       125
#    macro avg       0.46      0.45      0.45       125
# weighted avg       0.44      0.43      0.43       125
#
# Confusion_Matrix :

# %% [markdown]
# ## DF_SIFT_GCM

# %%
num_df = 2
_,List_DF_without_header = path_build(PATH_DATA_CSV)
print("Data Features Study : ",List_DF_without_header[num_df][0])
#Data preparation
X,y = split_data_without_head(List_DF_without_header[num_df][1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
randomizedsearch = Hyperparameter_tuning_GaussianNB(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
# Out:
# Data Features Study :  DF_SIFT_GCM.csv
# [INFO] Applying took 0.35 seconds

# %%
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# Model Performance
# Average Error: 0.48 %.
# Accuracy = 0.52%.
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        22
#            1       0.65      0.96      0.77        25
#            2       0.40      0.15      0.22        26
#            3       0.42      0.46      0.44        28
#            4       0.26      0.33      0.29        24
#
#     accuracy                           0.52       125
#    macro avg       0.55      0.53      0.51       125
# weighted avg       0.53      0.52      0.50       125
#
# Confusion_Matrix :

# %% [markdown]
# ## DF_SIFT_TH

# %%
num_df = 3
_,List_DF_without_header = path_build(PATH_DATA_CSV)
print("Data Features Study : ",List_DF_without_header[num_df][0])
#Data preparation
X,y = split_data_without_head(List_DF_without_header[num_df][1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
#Train data whith cross validation using Kfold = 5 and shuffle = True
randomizedsearch = Hyperparameter_tuning_GaussianNB(X_train,y_train, X_test, y_test)
#Using best estimator
clf = randomizedsearch.best_estimator_
# Out:
# Data Features Study :  DF_SIFT_TH.csv
# [INFO] Applying took 0.34 seconds

# %%
#evaluate best estimator
evaluate(clf,X_test,y_test)
# Out:
# Model Performance
# Average Error: 0.50 %.
# Accuracy = 0.50%.
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90        22
#            1       0.69      0.96      0.80        25
#            2       0.32      0.38      0.35        26
#            3       0.20      0.07      0.11        28
#            4       0.29      0.38      0.33        24
#
#     accuracy                           0.50       125
#    macro avg       0.50      0.52      0.50       125
# weighted avg       0.48      0.50      0.48       125
#
# Confusion_Matrix :
